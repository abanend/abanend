# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling import models, fitting
from astropy.modeling.functional_models import Sersic2D
from astropy.modeling.functional_models import Gaussian2D
from astropy.io import fits
import scipy.optimize
# %matplotlib inline

# %%
hdulist = fits.open("C:/Users/ANANDHU/Downloads/modtest_image.fits")

# %%
hdulist.info()
# Out:
# Filename: C:/Users/ANANDHU/Downloads/modtest_image.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (83, 83)   float32

# %%
hdu=hdulist[0]

# %%
hdu.data.shape
# Out:
# (83, 83)

# %%
plt.figure()
plt.imshow(hdu.data, cmap='gray')
plt.colorbar()
plt.plot(hdu.data)
plt.show()

# %%
plt.plot(hdu.data)
plt.show()

# %%
hdu.data[1].columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-7255c674b66f> in <module>
# ----> 1 hdu.data[1].columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
sersic_model = models.Sersic2D(1, 1, 4, 0, 0, 0)
fitter = fitting.LevMarLSQFitter()
sersic_fit = fitter(sersic_model, 0, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ec71fc774e4f> in <module>
#       1 sersic_model = models.Sersic2D(1, 1, 4, 0, 0, 0)
#       2 fitter = fitting.LevMarLSQFitter()
# ----> 3 sersic_fit = fitter(sersic_model, 0, 0)
#
# ~\anaconda3\lib\site-packages\astropy\modeling\fitting.py in wrapper(self, model, x, y, z, **kwargs)
#     174         else:
#     175
# --> 176             return func(self, model, x, y, z=z, **kwargs)
#     177
#     178     return wrapper
#
# ~\anaconda3\lib\site-packages\astropy\modeling\fitting.py in __call__(self, model, x, y, z, weights, maxiter, acc, epsilon, estimate_jacobian)
#     883             self.objective_function, init_values, args=farg, Dfun=dfunc,
#     884             col_deriv=model_copy.col_fit_deriv, maxfev=maxiter, epsfcn=epsilon,
# --> 885             xtol=acc, full_output=True)
#     886         _fitter_to_model_params(model_copy, fitparams)
#     887         self.fit_info.update(dinfo)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     386     if not isinstance(args, tuple):
#     387         args = (args,)
# --> 388     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     389     m = shape[0]
#     390
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      24 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      25                 output_shape=None):
# ---> 26     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      27     if (output_shape is not None) and (shape(res) != output_shape):
#      28         if (output_shape[0] != 1):
#
# ~\anaconda3\lib\site-packages\astropy\modeling\fitting.py in objective_function(self, fps, *args)
#     822         meas = args[-1]
#     823         if weights is None:
# --> 824             return np.ravel(model(*args[2: -1]) - meas)
#     825         else:
#     826             return np.ravel(weights * (model(*args[2: -1]) - meas))
#
# ~\anaconda3\lib\site-packages\astropy\modeling\core.py in __call__(self, model_set_axis, with_bounding_box, fill_value, equivalencies, inputs_map, *inputs, **new_inputs)
#     404
#     405             new_call = make_function_with_signature(
# --> 406                     __call__, args, kwargs, varargs='inputs', varkwargs='new_inputs')
#     407
#     408             # The following makes it look like __call__
#
# ~\anaconda3\lib\site-packages\astropy\modeling\core.py in __call__(self, *inputs, **kwargs)
#     382             def __call__(self, *inputs, **kwargs):
#     383                 """Evaluate this model on the supplied inputs."""
# --> 384                 return super(cls, self).__call__(*inputs, **kwargs)
#     385
#     386             # When called, models can take two optional keyword arguments:
#
# ~\anaconda3\lib\site-packages\astropy\modeling\core.py in __call__(self, *args, **kwargs)
#     919         that were specified when the model was instantiated.
#     920         """
# --> 921         new_args, kwargs = self._get_renamed_inputs_as_positional(*args, **kwargs)
#     922
#     923         return generic_call(self, *new_args, **kwargs)
#
# ~\anaconda3\lib\site-packages\astropy\modeling\core.py in _get_renamed_inputs_as_positional(self, *args, **kwargs)
#     954
#     955         if  n_all_args < self.n_inputs:
# --> 956             raise ValueError(f"Missing input arguments - expected {self.n_inputs}, got {n_all_args}")
#     957         elif n_all_args > self.n_inputs:
#     958             raise ValueError(f"Too many input arguments - expected {self.n_inputs}, got {n_all_args}")
#
# ValueError: Missing input arguments - expected 2, got 1

# %%
models.Sersic2D.param_names
# Out:
# ('amplitude', 'r_eff', 'n', 'x_0', 'y_0', 'ellip', 'theta')

# %%
plt.figure(figsize=(8,5))

# %%
print(sersic_fit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-202ca8ecb61c> in <module>
# ----> 1 print(sersic_fit)
#
# NameError: name 'sersic_fit' is not defined
