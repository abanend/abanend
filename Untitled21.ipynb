# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling import models, fitting
from astropy.io import fits

# %%
dat=fits.open("C:/Users/ANANDHU/Downloads/modtest_image.fits")[0].data

# %%
plt.figure()
plt.imshow(dat)
plt.colorbar()
plt.plot(dat)
plt.show()

# %%
plt.plot(dat)
plt.show()

# %%
x = np.arange(-1, 1, 2/dat.shape[1])
y = np.arange(-1, 1, 2/dat.shape[0])
xx, yy = np.meshgrid(x, y)

# %%
fit = fitting.LevMarLSQFitter()

# %%
mymod = models.Sersic2D()

# %%
p = fit(mymod,xx,yy,dat)
p
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# <Sersic2D(amplitude=8.56794197, r_eff=-0.06728728, n=0.62281422, x_0=-0.00531324, y_0=-0.00842102, ellip=-0.05424882, theta=-4.85278549e+08)>

# %%
plt.imshow(p(xx,yy))

# %%
plt.plot(p(xx,yy))
plt.show()

# %%
print(p)
# Out:
# Model: Sersic2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Parameters:
#        amplitude            r_eff         ...        theta
#     ---------------- -------------------- ... -------------------
#     8.56794196523113 -0.06728728100543076 ... -485278548.53776383

# %%
mymod = models.Gaussian2D()

# %%
q = fit(mymod,xx,yy,dat)
q
# Out:
# <Gaussian2D(amplitude=19.29892529, x_mean=-0.00547897, y_mean=-0.00845619, x_stddev=0.05733888, y_stddev=0.0551673, theta=-0.05579583)>

# %%
plt.imshow(q(xx,yy))

# %%
plt.plot(q(xx,yy))
plt.show()

# %%
print(q)
# Out:
# Model: Gaussian2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Parameters:
#         amplitude             x_mean        ...        theta
#     ----------------- --------------------- ... --------------------
#     19.29892528752676 -0.005478970065768326 ... -0.05579583075007318

# %%
print(p)
# Out:
# Model: Sersic2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Parameters:
#        amplitude            r_eff         ...        theta
#     ---------------- -------------------- ... -------------------
#     8.56794196523113 -0.06728728100543076 ... -485278548.53776383
