# %%
import numpy as np
import pyproffit
import matplotlib.pyplot as plt

# %%
dat=pyproffit.Data(imglink='C:/Users/ANANDHU/Downloads/modtest_image.fits')

# %%
fig = plt.figure(figsize=(20,20))
s1=plt.subplot(221)
plt.imshow(np.log10(dat.img),aspect='auto')
# Out:
# C:\Users\ANANDHU\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dat.dmfilth()
# Out:
# Applying high-pass filter
# Interpolating in the masked regions
# Filling holes

# %%
prof=pyproffit.Profile(dat,center_choice='centroid',maxrad=45.,binsize=20.,centroid_region=30.)
# Out:
# Computing centroid and ellipse parameters using principal component analysis
# No approximate center provided, will search for the centroid within a radius of 30 arcmin from the center of the image
# Denoising image...
# Running PCA...
# Centroid position: 42.402144772117964 42.38069705093834
# Corresponding FK5 coordinates:  0.03956032171581825 0.03595710455764056
# Ellipse axis ratio and position angle: 1.0179910949654611 96.65089661156283

# %%
prof.SBprofile(ellipse_ratio=prof.ellratio,rotation_angle=prof.ellangle+180.)

# %%
prof.Plot()

# %%
def Model(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %%
cuspmod = pyproffit.Model(myModel)

# %%
fitcusp = pyproffit.Fitter(model=cuspmod, profile=prof)
fitcusp.Migrad()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-94-cd695f5e9ea2> in <module>
# ----> 1 fitcusp = pyproffit.Fitter(model=cuspmod, profile=prof)
#       2 fitcusp.Migrad()
#
# ~\anaconda3\lib\site-packages\pyproffit\fitting.py in __init__(self, model, profile, method, fitlow, fithigh, **kwargs)
#     207
#     208             # Construct iminuit object
# --> 209             minuit = iminuit.Minuit(chi2, **kwargs)
#     210         elif method == 'cstat':
#     211             if profile.counts is None:
#
# ~\anaconda3\lib\site-packages\iminuit\minuit.py in __init__(self, fcn, grad, name, *args, **kwds)
#     577             raise RuntimeError(
#     578                 "starting value(s) are required"
# --> 579                 + (f" for {' '.join(name)}" if name else "")
#     580             )
#     581
#
# RuntimeError: starting value(s) are required for sigma

# %%
prof.Plot(model=cuspmod)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-272158c62658> in <module>
# ----> 1 prof.Plot(model=cuspmod)
#
# ~\anaconda3\lib\site-packages\pyproffit\profextract.py in Plot(self, model, hmcmod, outfile, axes, figsize, fontsize, xscale, yscale, fmt, markersize, lw, data_color, bkg_color, model_color, **kwargs)
#     926             plt.plot(rads, self.bkgprof, color=bkg_color, lw=lw, label='Background')
#     927         if model is not None:
# --> 928             tmod = model.model(rads, *model.params)
#     929             if self.psfmat is not None:
#     930                 tmod = np.dot(self.psfmat, tmod)
#
# TypeError: myModel() argument after * must be an iterable, not NoneType
