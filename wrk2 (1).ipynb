# %%
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.rc

# %%
from astropy.io import fits

# %%
hdu.list=fits.open("C:/Users/ANANDHU/Downloads/modtest_image.fits")

# %%
hdulist.info()
# Out:
# Filename: C:/Users/ANANDHU/Downloads/modtest_image.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (83, 83)   float32

# %%
hdu.data.shape
# Out:
# (83, 83)

# %%
plt.figure()
plt.imshow(hdu.data, cmap='gray')
plt.colorbar()

# %%
print('Min:', np.min(hdu.data))
print('Max:', np.max(hdu.data))
print('Mean:', np.mean(hdu.data))
print('Stdev:', np.std(hdu.data))
# Out:
# Min: -1.7071093
# Max: 20.623455
# Mean: 0.11342368
# Stdev: 1.0930094

# %%
print(type(hdu.data.flatten()))
# Out:
# <class 'numpy.ndarray'>

# %%
NBINS = 1000
histogram = plt.hist(hdu.data.flatten(), NBINS)
